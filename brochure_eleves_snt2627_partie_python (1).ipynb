# %% [markdown]
# ## 2. Initiation à python
# ### 1) Introduction
# #### Programmer un ordinateur
# Un programme est une suite d’instructions regrouper dans un ou plusieurs fichiers (documents) Programmer un ordinateur c’est créer des programmes capables d’interagir avec le matériel de l’ordinateur et/ou avec d’autres programmes appelés logiciels.
#
# Un ordinateur sans programmes est donc sans intérêt.
#
# #### Présentation de Python
# Python est un langage de programmation de haut niveau, libre et gratuit, conçu en 1989 par Guido Van Rossum, informaticien et mathématicien néerlandais.
# Il existe plusieurs éditeurs python. On utilisera souvent le pyscripter (Edupython), Spyder ou Jupyter.
# • Python est fourni avec de nombreux outils sous forme de bibliothèques (
# ensemble de fonctionnalités ).
# Par exemple la nombre pi ou la racine carré d'un nombre de la bibliothèque math
#
# ```
# import math
# nombre_pi=math.pi
# nombre = 16
# racine = math.sqrt(nombre)
# ```
# #### Présentation de Notebook de Jupyter
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2) Équivalences entre langage naturel et python
# #### a) Affectation d’une valeur à une variable x
# ![memento_algo_python.png](attachment:memento_algo_python.png)

# %% [markdown]
# #### Exercice n°17
# Compléter le code du script python ci-dessous pour qu’il corresponde à l’algorithme en langage naturel.
#
# ![Capture%20d'%C3%A9cran%202026-09-19%20204857.png](attachment:Capture%20d'%C3%A9cran%202026-09-19%20204857.png)

# %%
# Compléter votre code ici

distance = ...
temps = ...
vitesse = ...
print(vitesse)

# %% [markdown]
#  #### Exercice n°18
#
# Compléter le script python ci-dessous pour qu’il affiche la valeur de la diagonale d’un rectangle après avoir saisir sa
# largeur et sa longueur :
#
# ![image.png](attachment:image.png)

# %%
# Recopier et compléter ici

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#  Tester cet exemple ici

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cas particulier de la comparaison de deux réels de type float (qui ne sont pas représentés de façon exacte en informatique) :
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°19
# Compléter le code du script python ci-dessous pour qu'il corresponde à l'algorithme en langage naturel.
# ![image-2.png](attachment:image-2.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# #### Exercice n°20
# Parmi les quatre scripts python ci-dessous, déterminer le seul valide indiquant le plus grand de deux entiers.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°21
#
# On considère l'expression $A(x) =\dfrac{1}{(x − 1)\sqrt x}$ où x est un réel.
# Compléter le code du script python ci-dessous pour qu’il corresponde à l’algorithme en langage naturel.
#
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  Exercice n°22
#
# Compléter le code du script python ci-dessous pour qu’il corresponde à l’algorithme en langage naturel dont le but
# est de calculer la somme $1 + 2 + 3 + ··· + 99 + 100$.
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
#  #### Exercice n°23
#
# Parmi les quatre scripts python ci-dessous, déterminer le seul valide qui permet de calculer la somme $\sqrt{1}+\sqrt{2}+\sqrt{3}+\cdots +\sqrt{49}+\sqrt{50}$
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### • Rappel :
# ces boucles permettent de répéter des instructions tant qu’une certaine condition est vérifiée. La condition
# en question s’exprime en python de la même façon qu’avec un if.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°24
# Compléter le code du script python ci-dessous pour qu’il corresponde à l’algorithme en langage naturel dont le but
# est de déterminer le premier entier n tel que le produit $1 × 2 × 3 × ··· × n$ dépasse 10000 .
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# #### Exercice n°25
# Parmi les quatre scripts python ci-dessous, déterminer le seul valeur indiquant le plus petit entier n tel que $0,9^n \le 0,001$
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°26
# La formule de conversion entre la valeur d’une température en degrés farenheit et sa valeur en degrés celsius est la suivante :
# $\text{degrés Celsius} = \dfrac{5 \times \text{(degrés Fahrenheit)} − 160}{
# 9}$
#
# Compléter le code du script python ci-dessous pour qu’il donne la valeur en degrés celsius d’une température de 100
# et de 200 degrés farenheit.
#
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# ### 3) Application
# #### Exercice n°27
# Compléter le code du script python ci-dessous pour qu'il corresponde à l'algorithme en langage naturel.
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# #### Exercice n°28
# Que fait ce script python ?
#
# ```
# from math import*
# i=0
# while i*sqrt(i)<500:
#     i=i+1
# print(i)
# ```

# %% [markdown]
# Réponse :  ....
# ...

# %%
# Out:
# 63

# %% [markdown]
# #### Exercice n°29
# La valeur d’une voiture était de 20 000 euros en 2018. On suppose qu’elle est multipliée par 0,9 chaque année.
# Compléter le script python ci-dessous pour qu'il indique la première année à partir de laquelle la valeur de la voiture sera inférieure ou égale à 12000 euros.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°30
#
# Un ticket de tramway coûte 1 euro sans abonnement. Avec un abonnement annuel de 30 euros, le ticket ne coûte plus que 0,75 euros. Déterminer parmi les quatre scripts python ci-dessous le seul valide qui affiche, aprés avoir entré le nombre de tickets achetés n, si prendre un abonnement est rentable :
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice n°31
# Durant une année un individu a acheté n DVD valant 15 euros piéce et p livres valant 22 euros piéce. Compléter le script python ci-dessous pour qu’il indique si cet individu a dépensé plus de 300 euros en dvd et livres ou non :
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# #### Exercice n°32
# Un automobiliste roule à 90 km · h−1 pendant 2 heures, puis roule à 120 km · h−1. Compléter le script python ci-
# dessous pour qu’il indique le nombre de kilométres parcourus en fonction du temps de parcours exprimé en heures :
# ![image.png](attachment:image.png)

# %%
# Recopier Compléter votre code ici  ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
